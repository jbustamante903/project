# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d fedesoriano/california-housing-prices-data-extra-features
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fedesoriano/california-housing-prices-data-extra-features
# License(s): copyright-authors
# ...
# 100% 952k/952k [00:00<00:00, 1.89MB/s]
